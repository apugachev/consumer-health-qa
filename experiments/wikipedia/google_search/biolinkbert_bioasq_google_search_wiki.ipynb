# %% [markdown]
# ## Source: Wikipedia
# ## Retriever: Google Search
# ## Model: BioLinkBERT (BioASQ)

# %%
import torch
from sklearn.metrics import classification_report, roc_auc_score

import sys
sys.path.append("../../") # use utils

import utils
import importlib
importlib.reload(utils)

from utils import calc_auc

# %%
from transformers import AutoTokenizer, BertForSequenceClassification, BertModel, DataCollatorWithPadding

model_name = "<path_to_bio-linkbert-large__bioasq_hf>"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = BertForSequenceClassification.from_pretrained(model_name)
model.eval()
print("OK")
# Out:
# OK

# %%
def predict(question, passage):
    sequence = tokenizer.encode_plus(
        question, 
        passage, 
        return_tensors="pt",
        max_length=512,
        truncation=True
    )['input_ids']

    logits = model(sequence)[0]
    probabilities = torch.softmax(logits, dim=1).detach().cpu().tolist()[0]
    proba_yes = probabilities[1]
    
    return proba_yes

# %%
init_data = pd.read_csv("../../../data/data_to_process.csv")
print(len(init_data))
init_data.head(3)
# Out:
# 113
#   data_source query_id                                        description  \
# 0        2019        1  Can cranberries prevent urinary tract infections?
# 1        2019        3  Can acupuncture be effective for people with e...
# 2        2019        5                 Can acupuncture prevent migraines?
#
#                                   query  label
# 0  cranberries urinary tract infections    0.0
# 1                  acupuncture epilepsy    0.0
# 2                  acupuncture migraine    1.0

# %% [markdown]
# ## Keywords

# %%
raw_df = pd.read_csv("../../../data/google_search_wiki/wikipedia_articles_keywords.csv")
df = (
    raw_df
    .merge(init_data, on=["data_source", "query_id", "label"])
    .dropna()
)
print(len(df))
df.head(1)
# Out:
# 519
#                         query_processed article_title  \
# 0  cranberries urinary tract infections     Cranberry
#
#                                            paragraph  serp_position  \
# 0  A comprehensive review in 2012 of available re...            1.0
#
#   title_common_tokens  num_title_common_tokens  \
# 0       ['cranberry']                      1.0
#
#                       tokens_to_find            paragraph_common_tokens  \
# 0  ['urinary', 'infection', 'tract']  ['urinary', 'infection', 'tract']
#
#    num_paragraph_common_tokens  paragraph_number_in_article query_id  \
# 0                          3.0                         82.0        1
#
#   data_source  label                                        description  \
# 0        2019    0.0  Can cranberries prevent urinary tract infections?
#
#                                   query
# 0  cranberries urinary tract infections

# %%
results = []

for _, row in pb(df.iterrows(), max_value=len(df)):
    results.append(predict(row.description, row.paragraph))
# Out:
# 100% (519 of 519) |######################| Elapsed Time: 0:14:49 Time:  0:14:49

# %%
df['prediction'] = results
df.head(1)
# Out:
#                         query_processed article_title  \
# 0  cranberries urinary tract infections     Cranberry
#
#                                            paragraph  serp_position  \
# 0  A comprehensive review in 2012 of available re...            1.0
#
#   title_common_tokens  num_title_common_tokens  \
# 0       ['cranberry']                      1.0
#
#                       tokens_to_find            paragraph_common_tokens  \
# 0  ['urinary', 'infection', 'tract']  ['urinary', 'infection', 'tract']
#
#    num_paragraph_common_tokens  paragraph_number_in_article query_id  \
# 0                          3.0                         82.0        1
#
#   data_source  label                                        description  \
# 0        2019    0.0  Can cranberries prevent urinary tract infections?
#
#                                   query  prediction
# 0  cranberries urinary tract infections     0.04461

# %%
df.to_csv("predictions/biolinkbert_bioasq_google_search_wiki_preds_keywords.csv", index=0)

# %% [markdown]
# ## Calc metrics

# %%
init_data = pd.read_csv("../data_to_process.csv").query("data_source != 'wh_topics'")
print(len(init_data))
init_data.head(3)
# Out:
# 113
#   data_source query_id                                        description  \
# 0        2019        1  Can cranberries prevent urinary tract infections?
# 1        2019        3  Can acupuncture be effective for people with e...
# 2        2019        5                 Can acupuncture prevent migraines?
#
#                                   query  label
# 0  cranberries urinary tract infections    0.0
# 1                  acupuncture epilepsy    0.0
# 2                  acupuncture migraine    1.0

# %%
df = pd.read_csv("predictions/biolinkbert_bioasq_google_search_wiki_preds_keywords.csv")
print(len(df))
df.head(2)
# Out:
# 519
#                         query_processed    article_title  \
# 0  cranberries urinary tract infections        Cranberry
# 1  cranberries urinary tract infections  Cranberry juice
#
#                                            paragraph  serp_position  \
# 0  A comprehensive review in 2012 of available re...            1.0
# 1  Cranberry juice is the liquid juice of the cra...            2.0
#
#   title_common_tokens  num_title_common_tokens  \
# 0       ['cranberry']                      1.0
# 1       ['cranberry']                      1.0
#
#                       tokens_to_find            paragraph_common_tokens  \
# 0  ['urinary', 'infection', 'tract']  ['urinary', 'infection', 'tract']
# 1  ['urinary', 'infection', 'tract']  ['urinary', 'infection', 'tract']
#
#    num_paragraph_common_tokens  paragraph_number_in_article query_id  \
# 0                          3.0                         82.0        1
# 1                          3.0                          0.0        1
#
#   data_source  label                                        description  \
# 0        2019    0.0  Can cranberries prevent urinary tract infections?
# 1        2019    0.0  Can cranberries prevent urinary tract infections?
#
#                                   query  prediction
# 0  cranberries urinary tract infections    0.044610
# 1  cranberries urinary tract infections    0.077757

# %%
agg_types = ["avg", "top1", "norm_linear", "norm_log"]
data_source_types = sorted(df.data_source.unique().tolist()) + ["all"]
data_source_types
# Out:
# ['2019', '2021', 'health_belief', 'misbelief', 'all']

# %%
df_filled = (
    df
    .merge(init_data, how='outer', on=["query", "description", 'query_id', 'data_source', "label"])
    .fillna({"prediction": 0.5})
)
print(len(df_filled))
df_filled.tail(5)
# Out:
# 538
#     query_processed article_title paragraph  serp_position  \
# 533             NaN           NaN       NaN            NaN
# 534             NaN           NaN       NaN            NaN
# 535             NaN           NaN       NaN            NaN
# 536             NaN           NaN       NaN            NaN
# 537             NaN           NaN       NaN            NaN
#
#     title_common_tokens  num_title_common_tokens tokens_to_find  \
# 533                 NaN                      NaN            NaN
# 534                 NaN                      NaN            NaN
# 535                 NaN                      NaN            NaN
# 536                 NaN                      NaN            NaN
# 537                 NaN                      NaN            NaN
#
#     paragraph_common_tokens  num_paragraph_common_tokens  \
# 533                     NaN                          NaN
# 534                     NaN                          NaN
# 535                     NaN                          NaN
# 536                     NaN                          NaN
# 537                     NaN                          NaN
#
#      paragraph_number_in_article query_id    data_source  label  \
# 533                          NaN      206      misbelief    0.0
# 534                          NaN      212      misbelief    1.0
# 535                          NaN      213      misbelief    1.0
# 536                          NaN      214      misbelief    1.0
# 537                          NaN     12_h  health_belief    1.0
#
#                                description                             query  \
# 533       Does aloe help for a runny nose?              aloe help runny nose
# 534         Does echinacea boost immunity?          echinacea boost immunity
# 535             Does honey boost immunity?              honey boost immunity
# 536              Does garlic kill viruses?               garlic kill viruses
# 537  Does cialis treat enlarged prostrate?  cialis treats enlarged prostrate
#
#      prediction
# 533         0.5
# 534         0.5
# 535         0.5
# 536         0.5
# 537         0.5

# %%
assert 113 == len(df_filled.drop_duplicates(["query_id", "data_source"]))

# %%
metrics = {item: [] for item in data_source_types}

for data_source in data_source_types:
    for agg_type in agg_types:
        if data_source == "all":
            metrics[data_source].append(calc_auc(df_filled, agg_type))
        else:
            df_cut = df_filled.query(f"data_source == '{data_source}'")
            metrics[data_source].append(calc_auc(df_cut, agg_type))

metrics_df = pd.DataFrame(metrics, index=agg_types).round(4)
metrics_df
# Out:
#                2019    2021  health_belief  misbelief     all
# avg          0.5848  0.5792         0.7083     0.5536  0.5678
# top1         0.6990  0.4464         0.5833     0.4643  0.5489
# norm_linear  0.6021  0.5408         0.7083     0.5536  0.5659
# norm_log     0.6090  0.5280         0.7083     0.5357  0.5665

# %% [markdown]
# ## Question

# %%
raw_df = pd.concat((
    pd.read_csv("../../../data/google_search_wiki/wikipedia_articles_question.csv"),
))

df = (
    raw_df
    .merge(init_data, on=["data_source", "query_id", "label"])
    .dropna()
)

print(len(df))
df.head(1)
# Out:
# 627
#                                      query_processed article_title  \
# 0  Can cranberries prevent urinary tract infections?     Cranberry
#
#                                            paragraph  serp_position  \
# 0  A comprehensive review in 2012 of available re...            1.0
#
#   title_common_tokens  num_title_common_tokens  \
# 0       ['cranberry']                      1.0
#
#                                       tokens_to_find  \
# 0  ['prevent', 'tract', 'urinary', 'can', 'infect...
#
#              paragraph_common_tokens  num_paragraph_common_tokens  \
# 0  ['urinary', 'infection', 'tract']                          3.0
#
#    paragraph_number_in_article query_id data_source  label  \
# 0                         82.0        1        2019    0.0
#
#                                          description  \
# 0  Can cranberries prevent urinary tract infections?
#
#                                   query
# 0  cranberries urinary tract infections

# %%
results = []

for _, row in pb(df.iterrows(), max_value=len(df)):
    results.append(predict(row.description, row.paragraph))
# Out:
# 100% (627 of 627) |######################| Elapsed Time: 0:18:58 Time:  0:18:58

# %%
df['prediction'] = results
df.head(1)
# Out:
#                                      query_processed article_title  \
# 0  Can cranberries prevent urinary tract infections?     Cranberry
#
#                                            paragraph  serp_position  \
# 0  A comprehensive review in 2012 of available re...            1.0
#
#   title_common_tokens  num_title_common_tokens  \
# 0       ['cranberry']                      1.0
#
#                                       tokens_to_find  \
# 0  ['prevent', 'tract', 'urinary', 'can', 'infect...
#
#              paragraph_common_tokens  num_paragraph_common_tokens  \
# 0  ['urinary', 'infection', 'tract']                          3.0
#
#    paragraph_number_in_article query_id data_source  label  \
# 0                         82.0        1        2019    0.0
#
#                                          description  \
# 0  Can cranberries prevent urinary tract infections?
#
#                                   query  prediction
# 0  cranberries urinary tract infections     0.04461

# %%
df.to_csv("predictions/biolinkbert_bioasq_google_search_wiki_preds_question.csv", index=0)

# %% [markdown]
# ## Calc Metrics

# %%
df = pd.read_csv("predictions/biolinkbert_bioasq_google_search_wiki_preds_question.csv").drop("label", axis=1)
print(len(df))
df.head(2)
# Out:
# 627
#                                      query_processed article_title  \
# 0  Can cranberries prevent urinary tract infections?     Cranberry
# 1  Can cranberries prevent urinary tract infections?     Cranberry
#
#                                            paragraph  serp_position  \
# 0  A comprehensive review in 2012 of available re...            1.0
# 1  Cranberries are a group of evergreen dwarf shr...            1.0
#
#   title_common_tokens  num_title_common_tokens  \
# 0       ['cranberry']                      1.0
# 1       ['cranberry']                      1.0
#
#                                       tokens_to_find  \
# 0  ['prevent', 'tract', 'urinary', 'can', 'infect...
# 1  ['prevent', 'tract', 'urinary', 'can', 'infect...
#
#              paragraph_common_tokens  num_paragraph_common_tokens  \
# 0  ['urinary', 'infection', 'tract']                          3.0
# 1                            ['can']                          1.0
#
#    paragraph_number_in_article query_id data_source  \
# 0                         82.0        1        2019
# 1                          0.0        1        2019
#
#                                          description  \
# 0  Can cranberries prevent urinary tract infections?
# 1  Can cranberries prevent urinary tract infections?
#
#                                   query  prediction
# 0  cranberries urinary tract infections    0.044610
# 1  cranberries urinary tract infections    0.123621

# %%
df_filled = (
    df
    .merge(init_data, how='outer', on=["query", "description", 'query_id', 'data_source'])
    .fillna({"prediction": 0.5})
)
print(len(df_filled))
df_filled.tail(5)
# Out:
# 643
#     query_processed article_title paragraph  serp_position  \
# 638             NaN           NaN       NaN            NaN
# 639             NaN           NaN       NaN            NaN
# 640             NaN           NaN       NaN            NaN
# 641             NaN           NaN       NaN            NaN
# 642             NaN           NaN       NaN            NaN
#
#     title_common_tokens  num_title_common_tokens tokens_to_find  \
# 638                 NaN                      NaN            NaN
# 639                 NaN                      NaN            NaN
# 640                 NaN                      NaN            NaN
# 641                 NaN                      NaN            NaN
# 642                 NaN                      NaN            NaN
#
#     paragraph_common_tokens  num_paragraph_common_tokens  \
# 638                     NaN                          NaN
# 639                     NaN                          NaN
# 640                     NaN                          NaN
# 641                     NaN                          NaN
# 642                     NaN                          NaN
#
#      paragraph_number_in_article query_id    data_source  \
# 638                          NaN      205      misbelief
# 639                          NaN      206      misbelief
# 640                          NaN      212      misbelief
# 641                          NaN      213      misbelief
# 642                          NaN     12_h  health_belief
#
#                                description                             query  \
# 638          Does garlic help with thrush?                garlic help thrush
# 639       Does aloe help for a runny nose?              aloe help runny nose
# 640         Does echinacea boost immunity?          echinacea boost immunity
# 641             Does honey boost immunity?              honey boost immunity
# 642  Does cialis treat enlarged prostrate?  cialis treats enlarged prostrate
#
#      prediction  label
# 638         0.5    0.0
# 639         0.5    0.0
# 640         0.5    1.0
# 641         0.5    1.0
# 642         0.5    1.0

# %%
assert 113 == len(df_filled.drop_duplicates(["query_id", "data_source"]))

# %%
metrics = {item: [] for item in data_source_types}

for data_source in data_source_types:
    for agg_type in agg_types:
        if data_source == "all":
            metrics[data_source].append(calc_auc(df_filled, agg_type))
        else:
            df_cut = df_filled.query(f"data_source == '{data_source}'")
            metrics[data_source].append(calc_auc(df_cut, agg_type))

metrics_df = pd.DataFrame(metrics, index=agg_types).round(4)
metrics_df
# Out:
#                2019    2021  health_belief  misbelief     all
# avg          0.5260  0.5712          0.875     0.4286  0.5296
# top1         0.5363  0.5376          0.500     0.4286  0.5167
# norm_linear  0.5433  0.5856          0.875     0.4286  0.5517
# norm_log     0.5294  0.5872          0.875     0.4286  0.5564
